# %% [markdown]
# # 🌸 Flower Image Fine-Tuning using LoRA
#
# This notebook demonstrates the complete process of fine-tuning Stable Diffusion v1.5 using LoRA on the Oxford 102 Flowers Dataset.
#
# ## Technologies Used
# - Python
# - PyTorch
# - Hugging Face Diffusers
# - PEFT (LoRA)
# - Google Colab
#
# ## Workflow
# 1. Mount Google Drive
# 2. Install Dependencies
# 3. Prepare Dataset
# 4. Configure Training
# 5. Fine-Tune Stable Diffusion
# 6. Save LoRA Weights
# 7. Generate Images using the Fine-Tuned Model

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive/MyDrive

# %%
import os

project_path = "/content/drive/MyDrive/Flower_FineTuning"

os.makedirs(project_path, exist_ok=True)

# %cd $project_path

# %%
# %cd diffusers

# %%
# !pip install -e .

# %%
# %cd examples/text_to_image

# %%
# !pip uninstall -y torchao

# %%
# !pip show torchao

# %%
# !pip install -r requirements.txt

# %%
# !accelerate launch train_text_to_image_lora.py \
  --pretrained_model_name_or_path="runwayml/stable-diffusion-v1-5" \
  --dataset_name="imagefolder" \
  --train_data_dir="/content/drive/MyDrive/Flower_FineTuning/flower_dataset" \
  --caption_column="text" \
  --resolution=512 \
  --center_crop \
  --random_flip \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --learning_rate=1e-4 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=1000 \
  --checkpointing_steps=250 \
  --validation_prompt="A beautiful sunflower in a garden" \
  --validation_epochs=1 \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --output_dir="/content/drive/MyDrive/Flower_FineTuning/lora_output" \
  --seed=42
